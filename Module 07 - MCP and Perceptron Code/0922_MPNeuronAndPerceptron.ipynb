# %% [markdown]
# # Loading Dataset

# %%
import sklearn.datasets
import numpy as np

# %%
breast_cancer = sklearn.datasets.load_breast_cancer()

# %%
type(breast_cancer)
# Out:
# sklearn.utils.Bunch

# %%
x = breast_cancer.data
y = breast_cancer.target

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
print(breast_cancer.feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
import pandas as pd

# %%
df = pd.DataFrame(breast_cancer.data,columns = breast_cancer.feature_names)

# %%
df.head()
# Out:
#    mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
df['class'] = breast_cancer.target

# %%
df.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  class
# 0        17.99         10.38  ...                  0.11890      0
# 1        20.57         17.77  ...                  0.08902      0
# 2        19.69         21.25  ...                  0.08758      0
# 3        11.42         20.38  ...                  0.17300      0
# 4        20.29         14.34  ...                  0.07678      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
df.describe()
# Out:
#        mean radius  mean texture  ...  worst fractal dimension       class
# count   569.000000    569.000000  ...               569.000000  569.000000
# mean     14.127292     19.289649  ...                 0.083946    0.627417
# std       3.524049      4.301036  ...                 0.018061    0.483918
# min       6.981000      9.710000  ...                 0.055040    0.000000
# 25%      11.700000     16.170000  ...                 0.071460    0.000000
# 50%      13.370000     18.840000  ...                 0.080040    1.000000
# 75%      15.780000     21.800000  ...                 0.092080    1.000000
# max      28.110000     39.280000  ...                 0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
df['class'].value_counts()
# Out:
# 1    357
# 0    212
# Name: class, dtype: int64

# %%
print(breast_cancer.target_names)
# Out:
# ['malignant' 'benign']

# %%
df.groupby('class').mean()
# Out:
#        mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# class                             ...
# 0        17.462830     21.604906  ...        0.323468                 0.091530
# 1        12.146524     17.914762  ...        0.270246                 0.079442
#
# [2 rows x 30 columns]

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('class',axis = 1)
y = df['class']

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y)

# %%
x_train.shape
# Out:
# (426, 30)

# %%
x_train.head()
# Out:
#      mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 467        9.668         18.10  ...          0.3057                  0.07875
# 528       13.940         13.17  ...          0.2160                  0.07253
# 220       13.650         13.16  ...          0.2380                  0.08718
# 62        14.250         22.15  ...          0.2844                  0.11320
# 203       13.810         23.75  ...          0.4432                  0.10860
#
# [5 rows x 30 columns]

# %%
x_train.describe()
# Out:
#        mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# count   426.000000    426.000000  ...      426.000000               426.000000
# mean     13.845413     19.216620  ...        0.287950                 0.083400
# std       3.268113      4.211651  ...        0.059824                 0.017018
# min       6.981000      9.710000  ...        0.156500                 0.055040
# 25%      11.602500     16.092500  ...        0.250050                 0.071318
# 50%      13.310000     18.770000  ...        0.281100                 0.079900
# 75%      15.460000     21.695000  ...        0.313225                 0.091865
# max      25.220000     39.280000  ...        0.577400                 0.207500
#
# [8 rows x 30 columns]

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (569, 30) (426, 30) (143, 30)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (569, 30) (512, 30) (57, 30)

# %%
print(y.mean(),y_train.mean(),y_test.mean())
# Out:
# 0.6274165202108963 0.642578125 0.49122807017543857

# %% [markdown]
# Maintaining class ratios in train and test split as in the main dataset as much as possible.

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,stratify=y)

# %%
print(y.mean(),y_train.mean(),y_test.mean())
# Out:
# 0.6274165202108963 0.626953125 0.631578947368421

# %% [markdown]
# To have same split always (so that results are reproducible in future runs of the algorithm), we need to send random state argument, which is also referred to as seed of the splitter. The state doesn't matter.

# %%
x = df.drop('class',axis = 1)
y = df['class']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,stratify=y,random_state=1)

# %% [markdown]
# # Binarisation of input

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Each feature represented by a different color, with the samples over the x-axis.

# %%
plt.plot(x_train,'*')
plt.show()

# %% [markdown]
# Plotting the transpose of training set. Will showcase the different values for each feature i.e. the spread for each feature of the training set.

# %%
plt.plot(x_train.T, 'x')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# To binarise we can select a threshold value, above which the feature can take the value of 1, and below which it can take 0. The value can be the mean or median.

# %%
sample_col = x_train['mean area'].map(lambda x: 1 if x<1000 else 0)

# %%
plt.plot(sample_col,'*')
plt.show()

# %% [markdown]
# Not required to do it manually for each column of the dataframe, can be done using the cut function of the pandas module, which splits the column values into given number of bins with given set of labels.

# %%
pd.cut?

# %%
x_btrain = x_train.apply(pd.cut,bins=2,labels=[1,0])
x_btest = x_test.apply(pd.cut,bins=2,labels=[1,0])

# %%
plt.plot(x_btrain.T,'*')
plt.xticks(rotation='vertical')
plt.savefig('Binarised Input.png')
plt.show()

# %%
x_btrain = x_btrain.values
x_btest = x_btest.values

# %% [markdown]
# # MPNeuron

# %%
from random import randint

# %%
y_train_preds = []
optimal_train_b = 0
max_train_accuracy = 0

train_accuracies = []
for b in range(x_btrain.shape[1]):
  correct = 0
  for x,y in zip(x_btrain,y_train):
    y_pred = (np.sum(x)>=b)
    y_preds.append(y_pred)
    if y_pred==y:
      correct+=1
  accuracy = correct/x_btrain.shape[0]
  train_accuracies.append(accuracy)
  if accuracy>max_accuracy:
    max_accuracy = accuracy
    optimal_b = b
  # print(b,accuracy)

y_test_preds = []
optimal_test_b = 0
max_test_accuracy = 0

test_accuracies = []
for b in range(x_btest.shape[1]):
  correct = 0
  for x,y in zip(x_btest,y_test):
    y_pred = (np.sum(x)>=b)
    y_preds.append(y_pred)
    if y_pred==y:
      correct+=1
  accuracy = correct/x_btest.shape[0]
  test_accuracies.append(accuracy)
  if accuracy>max_accuracy:
    max_accuracy = accuracy
    optimal_b = b
  # print(b,accuracy)


# fig, axs = plt.subplots(2)
# fig.suptitle('Training and Testing Accuracies compared')
# axs[0].plot(list(range(b+1)),train_accuracies)
# axs[1].plot(list(range(b+1)),test_accuracies)

plt.plot(train_accuracies)
plt.plot(test_accuracies)
plt.ylim([0,1])
plt.show()

# %%
print(optimal_b, max_accuracy)
# Out:
# 22 0.9122807017543859

# %%
correct = 0
y_pred_test = []
for x,y in zip(x_btest,y_test):
  y_pred = (np.sum(x)>=optimal_b)
  y_pred_test.append(y_pred)
  if y_pred==y:
    correct+=1
  
print("test accuracy = ", correct/x_btest.shape[0])
# Out:
# test accuracy =  0.9122807017543859

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_pred_test,y_test)

# %%
accuracy
# Out:
# 0.9122807017543859

# %% [markdown]
# #MP Neuron Class

# %%
class MPNeuron:

  def __init__(self):
    self.b = None

  def model(self,x):
    return np.sum(x)>=self.b
  
  def predict(self,X):
    y_pred = []
    for x in X:
      result = self.model(x)
      y_pred.append(result)
    return np.array(y_pred)

  def fit(self,X,Y):
    accuracy = {}

    for b in range(X.shape[1]):
      self.b = b
      accuracy[b] = accuracy_score(self.predict(X),Y)
    best_b = max(accuracy, key = accuracy.get)
    self.b = best_b

    print("Optimal b", best_b)
    print("Max accuracy", accuracy[best_b])

  def train_test_analyse(self,X_train,Y_train,X_test,Y_test,test_size=None):
    y_train_preds = []
    y_test_preds = []
    optimal_train_b = 0
    optimal_test_b = 0
    max_train_accuracy = 0
    max_test_accuracy = 0 
    train_accuracies = []
    test_accuracies = []
    for b in range(x_btrain.shape[1]):
      train_correct = 0
      test_correct = 0
      for x,y in zip(x_btrain,y_train):
        y_pred = (np.sum(x)>=b)
        y_train_preds.append(y_pred)
        if y_pred==y:
          train_correct+=1
      accuracy = train_correct/x_btrain.shape[0]
      train_accuracies.append(accuracy)
      if accuracy>max_train_accuracy:
        max_train_accuracy = accuracy
        optimal_train_b = b
      # print(b,accuracy)

      for x,y in zip(x_btest,y_test):
        y_pred = (np.sum(x)>=b)
        y_test_preds.append(y_pred)
        if y_pred==y:
          test_correct+=1
      accuracy = test_correct/x_btest.shape[0]
      test_accuracies.append(accuracy)
      if accuracy>max_test_accuracy:
        max_test_accuracy = accuracy
        optimal_test_b = b

    plt.plot(train_accuracies)
    plt.plot(test_accuracies)
    plt.ylim([0,1])
    if test_size!=None:
      plt.savefig("Accuracy analysis for test size :"+str(test_size)+".png")
    plt.show()

# %%
mp_neuron = MPNeuron()

# %%
mp_neuron.train_test_analyse(x_btrain,y_train,x_btest,y_test,0.3)

# %%
# %%capture cap --no-stderr
print("test_size 0.3")
mp_neuron.fit(x_btrain,y_train)

# %%
with open('result.txt', 'a') as f:
     f.write(cap.stdout)

# %%
print(accuracy_score(mp_neuron.predict(x_btest),y_test))
print(mp_neuron.b)
# Out:
# 0.7807017543859649
# 28

# %% [markdown]
# # Perceptron Class

# %% [markdown]
# The class contains two hyperparameters, i.e. epochs, and learning rate. The class also contains the use of the concept of checkpoint s to extract the best possible weights correspoding to the highest training accuracy rather than relying on the last epoch for sub-optimal parameters for the model.
#
# Observation : initialisation with 0 gave unstable learning with learning rate,  whereas 1 led to stable learning with learning rate.

# %%
class Perceptron:

  def __init__(self):
    self.b = None
    self.w = None

  def model(self,x):
    return np.dot(self.w,x)>=self.b
  
  def predict(self,X):
    y_pred = []

    for x in X:
      result = self.model(x)
      y_pred.append(result)

    return np.array(y_pred)

  def fit(self,X,Y,epochs,lr):

    accuracy = []
    self.b = np.random.rand()
    self.w = np.random.randn(X.shape[1])
    max_accuracy = 0

    wt_matrix = []
    for i in range(epochs):
      for x,y in zip(X,Y):
        y_pred = self.model(x)
        if y==1 and y_pred==0:
          self.w= self.w + lr*x
          self.b= self.b + (lr)*1
        elif y==0 and y_pred==1:
          self.w= self.w - lr*x
          self.b= self.b - (lr)*1     
      plt.plot(self.w)
      latest_accuracy = accuracy_score(self.predict(X),Y)
      accuracy.append(latest_accuracy)
      wt_matrix.append(self.w)
      if latest_accuracy > max_accuracy:
        max_accuracy = latest_accuracy
        checkptw = self.w
        checkptb = self.b

      print("Completed epoch", i+1, ", Training Accuracy:",accuracy_score(self.predict(X),Y))
      print()
    plt.savefig("Weight Transition.png")
    plt.show()

    plt.plot(accuracy)
    plt.ylim([0,1])
    plt.savefig("Accuracy Transition")
    plt.show()

    self.w = checkptw
    self.b = checkptb

    return np.array(wt_matrix)

# %%
perceptron = Perceptron()

# %%
x_train = x_train.values
x_test = x_test.values

# %%
wt_matrix = perceptron.fit(x_train,y_train,1000,1)
# Out:
# Completed epoch 1 , Training Accuracy: 0.7839195979899497
#
# Completed epoch 2 , Training Accuracy: 0.7839195979899497
#
# Completed epoch 3 , Training Accuracy: 0.8969849246231156
#
# Completed epoch 4 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 5 , Training Accuracy: 0.907035175879397
#
# Completed epoch 6 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 7 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 8 , Training Accuracy: 0.8819095477386935
#
# Completed epoch 9 , Training Accuracy: 0.8969849246231156
#
# Completed epoch 10 , Training Accuracy: 0.8994974874371859
#
# Completed epoch 11 , Training Accuracy: 0.8919597989949749
#
# Completed epoch 12 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 13 , Training Accuracy: 0.8969849246231156
#
# Completed epoch 14 , Training Accuracy: 0.8994974874371859
#
# Completed epoch 15 , Training Accuracy: 0.864321608040201
#
# Completed epoch 16 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 17 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 18 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 19 , Training Accuracy: 0.864321608040201
#
# Completed epoch 20 , Training Accuracy: 0.8542713567839196
#
# Completed epoch 21 , Training Accuracy: 0.864321608040201
#
# Completed epoch 22 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 23 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 24 , Training Accuracy: 0.8417085427135679
#
# Completed epoch 25 , Training Accuracy: 0.8442211055276382
#
# Completed epoch 26 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 27 , Training Accuracy: 0.864321608040201
#
# Completed epoch 28 , Training Accuracy: 0.871859296482412
#
# Completed epoch 29 , Training Accuracy: 0.864321608040201
#
# Completed epoch 30 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 31 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 32 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 33 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 34 , Training Accuracy: 0.864321608040201
#
# Completed epoch 35 , Training Accuracy: 0.871859296482412
#
# Completed epoch 36 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 37 , Training Accuracy: 0.871859296482412
#
# Completed epoch 38 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 39 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 40 , Training Accuracy: 0.8618090452261307
#
# Completed epoch 41 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 42 , Training Accuracy: 0.8592964824120602
#
# Completed epoch 43 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 44 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 45 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 46 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 47 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 48 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 49 , Training Accuracy: 0.8366834170854272
#
# Completed epoch 50 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 51 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 52 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 53 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 54 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 55 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 56 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 57 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 58 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 59 , Training Accuracy: 0.8467336683417085
#
# Completed epoch 60 , Training Accuracy: 0.914572864321608
#
# Completed epoch 61 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 62 , Training Accuracy: 0.8467336683417085
#
# Completed epoch 63 , Training Accuracy: 0.914572864321608
#
# Completed epoch 64 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 65 , Training Accuracy: 0.8442211055276382
#
# Completed epoch 66 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 67 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 68 , Training Accuracy: 0.914572864321608
#
# Completed epoch 69 , Training Accuracy: 0.8542713567839196
#
# Completed epoch 70 , Training Accuracy: 0.9120603015075377
#
# Completed epoch 71 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 72 , Training Accuracy: 0.914572864321608
#
# Completed epoch 73 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 74 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 75 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 76 , Training Accuracy: 0.914572864321608
#
# Completed epoch 77 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 78 , Training Accuracy: 0.914572864321608
#
# Completed epoch 79 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 80 , Training Accuracy: 0.914572864321608
#
# Completed epoch 81 , Training Accuracy: 0.907035175879397
#
# Completed epoch 82 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 83 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 84 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 85 , Training Accuracy: 0.8517587939698492
#
# Completed epoch 86 , Training Accuracy: 0.907035175879397
#
# Completed epoch 87 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 88 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 89 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 90 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 91 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 92 , Training Accuracy: 0.914572864321608
#
# Completed epoch 93 , Training Accuracy: 0.914572864321608
#
# Completed epoch 94 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 95 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 96 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 97 , Training Accuracy: 0.9020100502512562
#
# Completed epoch 98 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 99 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 100 , Training Accuracy: 0.9045226130653267
#
# Completed epoch 101 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 102 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 103 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 104 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 105 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 106 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 107 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 108 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 109 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 110 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 111 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 112 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 113 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 114 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 115 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 116 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 117 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 118 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 119 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 120 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 121 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 122 , Training Accuracy: 0.9095477386934674
#
# Completed epoch 123 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 124 , Training Accuracy: 0.907035175879397
#
# Completed epoch 125 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 126 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 127 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 128 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 129 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 130 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 131 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 132 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 133 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 134 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 135 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 136 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 137 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 138 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 139 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 140 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 141 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 142 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 143 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 144 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 145 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 146 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 147 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 148 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 149 , Training Accuracy: 0.8567839195979899
#
# Completed epoch 150 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 151 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 152 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 153 , Training Accuracy: 0.8567839195979899
#
# Completed epoch 154 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 155 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 156 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 157 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 158 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 159 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 160 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 161 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 162 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 163 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 164 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 165 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 166 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 167 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 168 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 169 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 170 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 171 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 172 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 173 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 174 , Training Accuracy: 0.864321608040201
#
# Completed epoch 175 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 176 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 177 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 178 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 179 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 180 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 181 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 182 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 183 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 184 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 185 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 186 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 187 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 188 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 189 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 190 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 191 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 192 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 193 , Training Accuracy: 0.864321608040201
#
# Completed epoch 194 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 195 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 196 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 197 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 198 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 199 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 200 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 201 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 202 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 203 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 204 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 205 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 206 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 207 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 208 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 209 , Training Accuracy: 0.871859296482412
#
# Completed epoch 210 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 211 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 212 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 213 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 214 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 215 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 216 , Training Accuracy: 0.8668341708542714
#
# Completed epoch 217 , Training Accuracy: 0.871859296482412
#
# Completed epoch 218 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 219 , Training Accuracy: 0.871859296482412
#
# Completed epoch 220 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 221 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 222 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 223 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 224 , Training Accuracy: 0.871859296482412
#
# Completed epoch 225 , Training Accuracy: 0.8693467336683417
#
# Completed epoch 226 , Training Accuracy: 0.871859296482412
#
# Completed epoch 227 , Training Accuracy: 0.871859296482412
#
# Completed epoch 228 , Training Accuracy: 0.871859296482412
#
# Completed epoch 229 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 230 , Training Accuracy: 0.8743718592964824
#
# Completed epoch 231 , Training Accuracy: 0.871859296482412
#
# Completed epoch 232 , Training Accuracy: 0.871859296482412
#
# Completed epoch 233 , Training Accuracy: 0.8743718592964824
#
# Completed epoch
, Training Accuracy: 0.8869346733668342
#
# Completed epoch 826 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 827 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 828 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 829 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 830 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 831 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 832 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 833 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 834 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 835 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 836 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 837 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 838 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 839 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 840 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 841 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 842 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 843 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 844 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 845 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 846 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 847 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 848 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 849 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 850 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 851 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 852 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 853 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 854 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 855 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 856 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 857 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 858 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 859 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 860 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 861 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 862 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 863 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 864 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 865 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 866 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 867 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 868 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 869 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 870 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 871 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 872 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 873 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 874 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 875 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 876 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 877 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 878 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 879 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 880 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 881 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 882 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 883 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 884 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 885 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 886 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 887 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 888 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 889 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 890 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 891 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 892 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 893 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 894 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 895 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 896 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 897 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 898 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 899 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 900 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 901 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 902 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 903 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 904 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 905 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 906 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 907 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 908 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 909 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 910 , Training Accuracy: 0.8919597989949749
#
# Completed epoch 911 , Training Accuracy: 0.8919597989949749
#
# Completed epoch 912 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 913 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 914 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 915 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 916 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 917 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 918 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 919 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 920 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 921 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 922 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 923 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 924 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 925 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 926 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 927 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 928 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 929 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 930 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 931 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 932 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 933 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 934 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 935 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 936 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 937 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 938 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 939 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 940 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 941 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 942 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 943 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 944 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 945 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 946 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 947 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 948 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 949 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 950 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 951 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 952 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 953 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 954 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 955 , Training Accuracy: 0.9296482412060302
#
# Completed epoch 956 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 957 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 958 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 959 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 960 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 961 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 962 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 963 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 964 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 965 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 966 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 967 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 968 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 969 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 970 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 971 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 972 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 973 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 974 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 975 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 976 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 977 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 978 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 979 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 980 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 981 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 982 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 983 , Training Accuracy: 0.9246231155778895
#
# Completed epoch 984 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 985 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 986 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 987 , Training Accuracy: 0.8894472361809045
#
# Completed epoch 988 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 989 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 990 , Training Accuracy: 0.9170854271356784
#
# Completed epoch 991 , Training Accuracy: 0.9346733668341709
#
# Completed epoch 992 , Training Accuracy: 0.8844221105527639
#
# Completed epoch 993 , Training Accuracy: 0.9195979899497487
#
# Completed epoch 994 , Training Accuracy: 0.9221105527638191
#
# Completed epoch 995 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 996 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 997 , Training Accuracy: 0.9321608040201005
#
# Completed epoch 998 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 999 , Training Accuracy: 0.8869346733668342
#
# Completed epoch 1000 , Training Accuracy: 0.8869346733668342

# %%
accuracy_score(perceptron.predict(x_train),y_train)
# Out:
# 0.9346733668341709

# %%
accuracy_score(perceptron.predict(x_test),y_test)
# Out:
# 0.935672514619883

# %%
plt.plot(perceptron.w)
plt.savefig("Final Weight Graph for Perceptron")
plt.show()

# %%
plt.plot(wt_matrix[-1,:])
plt.show()

# %% [markdown]
# https://matplotlib.org/3.1.1/gallery/subplots_axes_and_figures/subplots_demo.html : Refer for subplots and multiple plots with good handle for each
#
# http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/: Refer for animations in jupyter notebook

# %%
# %matplotlib inline

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, wt_matrix.shape[1]))
ax.set_ylim((np.amin(wt_matrix), np.amax(wt_matrix)))

line, = ax.plot([], [], lw=2)

# %%
# animation function. This is called sequentially
def animate(i):
    x = list(range(wt_matrix.shape[1]))
    y = wt_matrix[i,:]
    line.set_data(x, y)
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate,frames=100, interval=200, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
