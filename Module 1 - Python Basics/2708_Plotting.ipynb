# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.random((10,1))
plt.plot(x)
plt.show()

# %%
plt.plot(x,'*')
plt.show()

# %%
y = np.power(x,0.5)
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.power(x,0.5)
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'*-')
plt.show()

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
sns.set()

# %%
ax = sns.lineplot(x,y)

# %%
p = np.array(range(10))

# %%
plt.plot(p)
plt.show()

# %%
sns.lineplot(x,y)
plt.show()

# %%
import pandas as pd
data = pd.read_csv("mobile_cleaned.csv")
data.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
ax = sns.scatterplot(x='stand_by_time',y='battery_capacity',data=data)

# %%
ax = sns.scatterplot(x='stand_by_time',y='battery_capacity',hue='thickness',data=data)

# %%
ax.figure.savefig("output.png")

# %%
ax = sns.distplot(data["stand_by_time"])

# %%
ax = sns.distplot(data["stand_by_time"],kde=False)

# %%
ax = sns.distplot(data['stand_by_time'],kde=False,rug=True)

# %%
ax = sns.distplot(data['stand_by_time'],kde=False,rug=True,bins=20)

# %%
ax.figure.savefig('output2.png')

# %%
ax = sns.boxplot(x='is_liked',y='battery_capacity',data=data)

# %%
ax = sns.boxplot(x='expandable_memory',y='price',data=data)

# %%
ax.figure.savefig("output3.png")

# %%
ax = sns.boxplot(x='expandable_memory',y='is_liked',data=data)

# %%
uniform_data = np.random.random((10,12))

# %%
ax = sns.heatmap(uniform_data)

# %%
ax.figure.savefig("output5.png")

# %%
d2 = np.random.random((2,10,12))

# %%
##Works only for 2d o/p

# ax = sns.heatmap(d2)

# %%
ax = sns.heatmap(uniform_data,cmap="YlGnBu")

# %%
sns.heatmap?

# %%
ax.figure.savefig("output4.png")

# %%
# !wget https://championballer.github.io/profile.jpg
# Out:
# --2019-08-27 10:07:24--  https://championballer.github.io/profile.jpg
# Resolving championballer.github.io (championballer.github.io)... 185.199.109.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to championballer.github.io (championballer.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95049 (93K) [image/jpeg]
# Saving to: ‘profile.jpg’
#
# profile.jpg         100%[===================>]  92.82K  --.-KB/s    in 0.02s
#
# 2019-08-27 10:07:24 (4.59 MB/s) - ‘profile.jpg’ saved [95049/95049]

# %%
# !ls
# Out:
# mobile_cleaned.csv  output3.png  output5.png  profile.jpg
# output2.png	    output4.png  output.png   sample_data

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('profile.jpg')

# %%
imgplot = plt.imshow(img)
